# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Extraction
#
# Let's see how to evaluate an agent's ability to use tools.

# %%
from langchain_benchmarks import clone_public_dataset, registry

# %% [markdown]
# For this code to work, please configure LangSmith environment variables with your credentials.

# %%
registry
# Out:
# Registry(tasks=[ToolUsageTask(name='Tool Usage - Typewriter (1 func)', dataset_id='placeholder', description='Environment with a single function that accepts a single letter as input, and "prints" it on a piece of paper.\n\nThe objective of this task is to evaluate the ability to use the provided tools to repeat a given input string.\n\nFor example, if the string is \'abc\', the tools \'a\', \'b\', and \'c\' must be invoked in that order.\n\nThe dataset includes examples of varying difficulty. The difficulty is measured by the length of the string.\n', create_environment=<function get_environment at 0x7f34137f4820>, instructions="Repeat the given string by using the provided tools. Do not write anything else or provide any explanations. For example, if the string is 'abc', you must invoke the tools 'a', 'b', and 'c' in that order. Please invoke the function with a single letter at a time."), ToolUsageTask(name='Tool Usage - Typewriter', dataset_id='placeholder', description="Environment with 26 functions each representing a letter of the alphabet.\n\nIn this variation of the typewriter task, there are 26 parameterless functions, where each function represents a letter of the alphabet (instead of a single function that takes a letter as an argument).\n\nThe object is to evaluate the ability of use the functions to repeat the given string.\n\nFor example, if the string is 'abc', the tools 'a', 'b', and 'c' must be invoked in that order.\n\nThe dataset includes examples of varying difficulty. The difficulty is measured by the length of the string.\n", create_environment=<function get_environment at 0x7f3413805280>, instructions="Repeat the given string by using the provided tools. Do not write anything else or provide any explanations. For example, if the string is 'abc', you must invoke the tools 'a', 'b', and 'c' in that order. Please invoke the functions without any arguments."), ToolUsageTask(name='Tool Usage - Relational Data', dataset_id='e95d45da-aaa3-44b3-ba2b-7c15ff6e46f5', description='Environment with fake data about users and their locations and favorite foods.\n\nThe environment provides a set of tools that can be used to query the data.\n\nThe objective of this task is to evaluate the ability to use the provided tools to answer questions about relational data.\n\nThe dataset contains 21 examples of varying difficulty. The difficulty is measured by the number of tools that need to be used to answer the question.\n\nEach example is composed of a question, a reference answer, and information about the sequence in which tools should be used to answer the question.\n\nSuccess is measured by the ability to answer the question correctly, and efficiently.\n', create_environment=<function get_environment at 0x7f34137f4e50>, instructions="Please answer the user's question by using the tools provided. Do not guess the answer. Keep in mind that entities like users,foods and locations have both a name and an ID, which are not the same."), ToolUsageTask(name='Multiverse Math', dataset_id='placeholder', description='An environment that contains a few basic math operations, but with altered results.\n\nFor example, multiplication of 5*3 will be re-interpreted as 5*3*1.1. The basic operations retain some basic properties, such as commutativity, associativity, and distributivity; however, the results are different than expected.\n\nThe objective of this task is to evaluate the ability to use the provided tools to solve simple math questions and ignore any innate knowledge about math.\n', create_environment=<function get_environment at 0x7f3413805820>, instructions='You are requested to solve math questions in an alternate mathematical universe. The rules of association, commutativity, and distributivity still apply, but the operations have been altered to yield different results than expected. Solve the given math questions using the provided tools. Do not guess the answer.'), ExtractionTask(name='Email Extraction', dataset_id='https ...

# %%
task = registry["Email Extraction"]
task
# Out:
# ExtractionTask(name='Email Extraction', dataset_id='https://smith.langchain.com/public/36bdfe7d-3cd1-4b36-b957-d12d95810a2b/d', description='A dataset of 42 real emails deduped from a spam folder, with semantic HTML tags removed, as well as a script for initial extraction and formatting of other emails from an arbitrary .mbox file like the one exported by Gmail.\n\nSome additional cleanup of the data was done by hand after the initial pass.\n\nSee https://github.com/jacoblee93/oss-model-extraction-evals.\n    ', schema=<class 'langchain_benchmarks.extraction.tasks.email_task.Email'>, instructions=ChatPromptTemplate(input_variables=['email'], messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template='You are an expert researcher.')), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['email'], template='What can you tell me about the following email? Make sure to extract the question in the correct format. Here is the email:\n ```\n{email}\n```'))]))

# %%
print(task.description)
# Out:
# A dataset of 42 real emails deduped from a spam folder, with semantic HTML tags removed, as well as a script for initial extraction and formatting of other emails from an arbitrary .mbox file like the one exported by Gmail.
#
# Some additional cleanup of the data was done by hand after the initial pass.
#
# See https://github.com/jacoblee93/oss-model-extraction-evals.

# %% [markdown]
# Clone the dataset associaetd with this task

# %%
clone_public_dataset(task.dataset_id, dataset_name=task.name)
# Out:
# Dataset Email Extraction already exists. Skipping.
# You can access the dataset at https://smith.langchain.com/o/e081f11e-fbd2-41b4-9fa8-5d76c76ef854/datasets/c652e524-8faf-4796-a0fd-d56415b7a5a6.

# %%
import pprint

pprint.pprint(task.schema.schema())
# Out:
# {'definitions': {'ToneEnum': {'description': 'The tone of the email.',
#                               'enum': ['positive', 'negative'],
#                               'title': 'ToneEnum',
#                               'type': 'string'}},
#  'description': 'Relevant information about an email.',
#  'properties': {'action_items': {'description': 'A list of action items '
#                                                 'requested by the email',
#                                  'items': {'type': 'string'},
#                                  'title': 'Action Items',
#                                  'type': 'array'},
#                 'sender': {'description': "The sender's name, if available",
#                            'title': 'Sender',
#                            'type': 'string'},
#                 'sender_address': {'description': "The sender's address, if "
#                                                   'available',
#                                    'title': 'Sender Address',
#                                    'type': 'string'},
#                 'sender_phone_number': {'description': "The sender's phone "
#                                                        'number, if available',
#                                         'title': 'Sender Phone Number',
#                                         'type': 'string'},
#                 'tone': {'allOf': [{'$ref': '#/definitions/ToneEnum'}],
#                          'description': 'The tone of the email.'},
#                 'topic': {'description': 'High level description of what the '
#                                          'email is about',
#                           'title': 'Topic',
#                           'type': 'string'}},
#  'required': ['action_items', 'topic', 'tone'],
#  'title': 'Email',
#  'type': 'object'}

# %% [markdown]
# ## Define an extraction chain
#
# Let's build an agent that we can use for evaluation.

# %%
from langchain_benchmarks.extraction.implementations import (
    create_openai_function_based_extractor,
)
from langchain.chat_models import ChatOpenAI

# %%
extraction_chain = create_openai_function_based_extractor(
    task.instructions, ChatOpenAI(model="gpt-3.5-turbo-16k", temperature=0), task.schema
)

# %%
extraction_chain.invoke(
    {
        "email": "Hello Dear MR. I want you to send me gold to get rich. First buy an envelope. Then open it and put some gold inside. Then close it and finally mail it to my address at 12345 My Gold Way. You can call me any time at 000-1212-1111."
    }
)
# Out:
# {'output': {'sender': 'Unknown',
#   'sender_phone_number': '000-1212-1111',
#   'sender_address': '12345 My Gold Way',
#   'action_items': ['Buy an envelope',
#    'Put gold inside',
#    'Close the envelope',
#    "Mail it to sender's address"],
#   'topic': 'Request to send gold',
#   'tone': 'positive'}}

# %% [markdown]
# Let's test that our agent works

# %% [markdown]
# ## Eval
#
# Let's evaluate an agent now

# %%
from langchain_benchmarks.extraction import get_eval_config
from langsmith.client import Client

# %%
client = Client()

# %%
eval_config = get_eval_config(ChatOpenAI(model="gpt-4"))

# %%
test_run = client.run_on_dataset(
    dataset_name=task.name,
    llm_or_chain_factory=extraction_chain,
    evaluation=eval_config,
    verbose=True,
    tags=["openai-functions"],
)
# Out:
# View the evaluation results for project 'test-worthwhile-sound-23' at:
# https://smith.langchain.com/o/e081f11e-fbd2-41b4-9fa8-5d76c76ef854/projects/p/7d5e8f03-26d1-4f2f-b954-7b8aff02a086?eval=true
#
# View all tests for Dataset Email Extraction at:
# https://smith.langchain.com/o/e081f11e-fbd2-41b4-9fa8-5d76c76ef854/datasets/c652e524-8faf-4796-a0fd-d56415b7a5a6
# [------------------------------------------------->] 42/42
#  Eval quantiles:
#                        0.25  0.5  0.75      mean  mode
# score_string:accuracy   0.3  0.3   0.7  0.471429   0.3

# %% [markdown]
# # Inspect
#
# Here, we'll take a look at the underlying results a little bit.
#
# A few things to note:
#
# * The correctness is 66% (so it's messing up a lot!)
# * The number of tool invocations made by the agent can be very large; e.g., 15 invocations, when only a single invocation was actually needed.

# %%
import pandas as pd

df = test_run.to_dataframe()
df = pd.json_normalize(df.to_dict(orient="records"))

# %%
df
# Out:
#     score_string:accuracy                                        input.email  \
# 0                     0.7  ---  \n|\n\n# We Provide Unique Financing Opti...
# 1                     0.3  ---  \n|  |  QUALIFY NOW  \n---  \n \n  \nHell...
# 2                     0.3  ---  \n|\n\nCostco  \n  \n---  \n  \nANSWER  \...
# 3                     0.3  ---|---  \n  \n|  \n---  \n  \n|  \n---  \n|\n...
# 4                     0.1  |  |  |  |  |\n\nOCTOBER 2023, VOL. 23 NO. 2  ...
# 5                     0.7  Hello,  \n  \nThis is Eli Zafrani from Getty A...
# 6                     0.3  | Auroras and Adventure Await in Anchorage  \n...
# 7                     0.7  Hi Jacob, it's Scott.  \n \n=0AIt's been the h...
# 8                     0.1  ---|---|---|---  \n  \nBook with Fall Sale Ext...
# 9                     0.3  ---  \n  \n|\n\nNewsom Signed Our Bill to Expa...
# 10                    0.3  -This message was sent from a trusted sender.\...
# 11                    0.3  It's always been a hassle to get more working ...
# 12                    0.7  _`I Am looking for a possible partnership with...
# 13                    0.7  USA Finance Solution offers 24/7 online access...
# 14                    0.7  Hi Jacob,\n\nWe are working to enhance our off...
# 15                    0.7  |  |  |  |  |  |\n\nHello Jacob, 👋\n\n  \n\nSp...
# 16                    0.7  **iCloud** ��  \n  \n# Failed to attempt payme...
# 17                    0.3  Hi!  \n  \nI just announced that I will be run...
# 18                    0.3  **Your **_Norton_** subscription has expired!*...
# 19                    0.3  Hello Jacob,\n\n  \n\nDo you know what Fortune...
# 20                    0.3  Bamboo Spa Grand Reopening Sale!\n\n|  |  \n--...
# 21                    0.7  ---  \n**Your credit score will be moving to C...
# 22                    0.7  Dear Jacob,  \n  \nYour opinion matters to us!...
# 23                    0.3  Solve the RedWordle\n\nWe know you won't let t...
# 24                    0.9  >>>>> On Monday, October 16, 2023 at 2:14 PM, ...
# 25                    0.3  USA Finance Solution offers 24/7online access ...
# 26                    0.3  ---  \n  |  |  Adventure alongside your friend...
# 27                    0.7  Happy Halloween, Jacob!\n\nYou may be a lover ...
# 28                    0.7  ---  \n  \n|\n\nWe Passed the Stop Dangerous P...
# 29                    0.7  Hello Jacob,\n\n  \n\nFor many small businesse...
# 30                    0.3  Hello Jacob,\n\n\n\nGreetings from Group Futur...
# 31                    0.3  ---  \n|\n\n# We Provide Unique Financing Opti...
# 32                    0.7  Many of you aren't just running businesses; yo...
# 33                    0.5  ####  Where sustainability meets style  \n  \n...
# 34                    0.3  **Would you like to add special touches to you...
# 35                    0.3  Your exclusive retreat at The Venetian Resort....
# 36                    0.3  ---|---|---|---  \n  \n|  \n---  \n **Limited ...
# 37                    0.3  Some travelers plan ahead; others prefer a bit...
# 38                    0.7  Consider all ways to give to  \nSave the Redwo...
# 39                    0.7  Hi there,\n\n |  \n---  \n  \nWe've updated ou...
# 40                    0.7  Hello Jacob!\n\n  \n\nHave you noticed thesurg...
# 41                    0.3  ---  \n|\n\nEvery business faces its set of cu...
#
#         output.output.sender  \
# 0   info@championadvance.com
# 1                 Sam at EMC
# 2                     Costco
# 3   info@championadvance.com
# 4                        NaN
# 5                Eli Zafrani
# 6                        NaN
# 7               Scott Wiener
# 8                        NaN
# 9                 Matt Haney
# 10                     Apple
# 11           Angelina Petrov
# 12                  Al.Nabil
# 13      USA Finance Solution
# 14                     Tanya
# 15                Sam at EMC
# 16                    iCloud
# 17      Senator Scott Wiener
# 18                    Norton
# 19                Sam at EMC
# 20             Bamboo Spa SF
# 21                    Intuit
# 22              EMC Research
# 23                       NaN
# 24           Angelina Petrov
# 25      USA Finance Solution
# 26             Niantic, Inc.
# 27             Basil the Bat
# 28                Matt Haney
# 29                Sam at EMC
# 30            Jennifer Trott
# 31  info@championadvance.com
# 32             EMC Financial
# 33         Uber Technologies
# 34
# 35                       NaN
# 36                       NaN
# 37    Dunhill Vacations Inc.
# 38                Tim Whalen
# 39           Crunchbase Team
# 40                Sam at EMC
# 41             EMC Financial
#
#                          output.output.sender_address  \
# 0                     42 Broadway, New York, NY 10004
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                     75 Broad St, New York, NY 10004
# 6                                                 NaN
# 7   312 Clay St. Suite 300 Oakland, CA 94607 Unite...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                 44 Wall Street, New York, NY 10005
# 12                                            unknown
# 13    1501 Hamburg Turnpike Suite 301 Wayne, NJ 07470
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20             2284 Union St, San Francisco, CA 94123
# 21    2800 E. Commerce Center Place, Tucson, AZ 85706
# 22                                                NaN
# 23                                                NaN
# 24                 44 Wall Street, New York, NY 10005
# 25                                                NaN
# 26        One Ferry Building, San Francisco, CA 94111
# 27                                                NaN
# 28  1021 O Street, Suite 5310, P.O. Box 942849, Sa...
# 29                                                NaN
# 30                                                NaN
# 31                    42 Broadway, New York, NY 10004
# 32  475 Washington Blvd, Suite 7, Marina Del Rey, ...
# 33                                                NaN
# 34
# 35                                                NaN
# 36                                                NaN
# 37  2307 W. Broward Blvd, Ste 402 - Fort Lauderdal...
# 38  Save the Redwoods League, 111 Sutter Street, 1...
# 39                                                NaN
# 40                                                NaN
# 41  475 Washington Blvd, Suite 7, Marina Del Rey, ...
#
#                            output.output.action_items  \
# 0   [Fill out the application, Provide last 3 mont...
# 1   [Check how much financing you're eligible to r...
# 2                                       [unsubscribe]
# 3                                                  []
# 4                                                  []
# 5   [Fill out updated application, Provide last 4 ...
# 6                                                  []
# 7   [Join re-election campaign as a founding donor...
# 8                                                  []
# 9                [visit my website, send me an email]
# 10                    [Claim Reward Now, UNSUBSCRIBE]
# 11                                                 []
# 12                     [reply for further discussion]
# 13                    [See Your Options, Unsubscribe]
# 14  [Share missing features or functionality, Sche...
# 15  [Tell us about your business and explore your ...
# 16                                [Update my payment]
# 17                                [buy tickets today]
# 18                           [Renew Now, unsubscribe]
# 19                            [qualify for financing]
# 20                                 [View Offer, RSVP]
# 21                              [Learn more, Sign up]
# 22       [Take the Survey, Click here to unsubscribe]
# 23                                                 []
# 24  [Check eligibility, Complete application onlin...
# 25                                                 []
# 26                                                 []
# 27  [Play RedWordle!, Download redwood-inspired Ja...
# 28               [visit my website, send me an email]
# 29  [Kickstart your funding application now and se...
# 30                                                 []
# 31                                                 []
# 32                   [GET STARTED, CHECK ELIGIBILITY]
# 33            [Request a ride using Comfort Electric]
# 34                                                 []
# 35                                                 []
# 36                                                 []
# 37          [Sign Up, Forward to Friend, Unsubscribe]
# 38  [Set up an annual contribution to Save the Red...
# 39  [Review the new versions of the governing term...
# 40  [Fill out application, Explore financing options]
# 41                   [GET STARTED, CHECK ELIGIBILITY]
#
#                                   output.output.topic output.output.tone  \
# 0                            Unique financing options           positive
# 1   Operational evolution and low-rate business loans           positive
# 2                                     Loyalty Program           positive
# 3                            Unique financing options           positive
# 4                                       Email Summary           positive
# 5                     Offer for extra working capital           positive
# 6            Auroras and Adventure Await in Anchorage           positive
# 7                Announcement of re-election campaign           positive
# 8                                    Fall Sale Extras           positive
# 9   Newsom Signed Our Bill to Expand Access to Add...           positive
# 10  You have been selected to get our BRAND NEW iP...           positive
# 11                     Information about loan options           positive
# 12    Possible partnership and investment opportunity           positive
# 13                                     Funding offers           positive
# 14  Identifying missing features or functionalitie...           positive
# 15                 EMC Financial - Business Financing           positive
# 16  Failed to attempt payment when renewing your C...           negative
# 17  Announcement of running for a third term in th...           positive
# 18                     Norton subscription expiration           negative
# 19                                  Financing options           positive
# 20                   Bamboo Spa Grand Reopening Sale!           positive
# 21  Your credit score will be moving to Credit Kar...           positive
# 22  Participation in a survey about local transpor...           positive
# 23                                Solve the RedWordle           positive
# 24                                         Loan offer           positive
# 25                                     Funding offers           positive
# 26                            New feature: Party Play           positive
# 27          Halloween fun at Save the Redwoods League           positive
# 28       Passing of the Stop Dangerous Pharmacies Act           positive
# 29  EMC Financial services for busy season prepara...           positive
# 30  Invitation to Future of SaaS Management Platfo...           positive
# 31                           Unique financing options           positive
# 32  Funding solutions for ambitious and resilient ...           positive
# 33                              Uber Comfort Electric           positive
# 34  Would you like to add special touches to your ...           positive
# 35           Exclusive retreat at The Venetian Resort           positive
# 36   Limited Time Up To 45% Savings on Culinary Tours           positive
# 37                                       Travel Deals           positive
# 38           Ways to give to Save the Redwoods League           positive
# 39                            Updated governing terms           positive
# 40                  Going green and financing options           positive
# 41  EMC Financial - Working Capital for Business R...           positive
#
#    reference.output.tone                             reference.output.topic  \
# 0               positive                   Financing options for businesses
# 1               positive                Business loan and credit line offer
# 2               positive  Invitation to participate in a Loyalty Program...
# 3               positive                   Financing options for businesses
# 4               positive        Princeton University Alumni News and Events
# 5               positive                      Loan offer from Getty Advance
# 6               positive            Travel and Tourism in Anchorage, Alaska
# 7               positive  Announcement of Senator Scott Wiener's run for...
# 8               positive                        Fall Cruise Sale Promotions
# 9               positive  Governor Newsom signing AB 816 to expand acces...
# 10              positive                  Promotion for a new iPhone 15 Pro
# 11              positive                             Business Loan Services
# 12              positive                    Investment Partnership Proposal
# 13              positive                            Business Funding Offers
# 14              positive  Feedback request for Neon's missing features o...
# 15              positive                   Business Financing Opportunities
# 16              negative        iCloud Storage Subscription Renewal Failure
# 17              positive  Campaign announcement and invitation to a cele...
# 18              negative   Norton Subscription Expiration and Renewal Offer
# 19              positive          Business Financing and Credit Lines Offer
# 20              positive                 Grand Reopening Sale at Bamboo Spa
# 21              positive    Credit score service transition to Credit Karma
# 22              positive  Invitation to Participate in Transportation Su...
# 23              positive     RedWordle Puzzle and Redwood Forests Education
# 24              positive           Loan Purchase Offer and Funding Services
# 25              positive                            Business funding offers
# 26              positive  Pokemon GO Halloween Event and Introduction of...
# 27              positive  Halloween Activities and Fun from Save the Red...
# 28              positive                      Stop Dangerous Pharmacies Act
# 29              positive               Business financing and loan services
# 30              positive  Invitation to the Future of SaaS Management Pl...
# 31              positive      Financing Options Offered by Champion Advance
# 32              positive                   Funding solutions for businesses
# 33              positive  Promotion of Uber Comfort Electric as a sustai...
# 34              positive                       Personalized Gifts Promotion
# 35              positive  Exclusive retreat offer at The Venetian Resort...
# 36              positive                 Travel and Culinary Tour Discounts
# 37              positive                         Travel and Vacation Offers
# 38              positive  Donation and Support for Save the Redwoods League
# 39              positive             Update of Crunchbase's governing terms
# 40              positive            Green Initiatives and Financing Options
# 41              positive        Business resilience and financing solutions
#
#    reference.output.sender                      reference.output.action_items  \
# 0         Champion Advance  [Start the financing process, Complete the one...
# 1               Sam at EMC  [Check how much financing you're eligible to r...
# 2               Enterprise  [Participate in the Loyalty Program, Receive a...
# 3         Champion Advance  [Start the financing process, Complete the one...
# 4                     None  [Send comments and questions to alumweb@prince...
# 5              Eli Zafrani  [Fill out the updated application, Provide the...
# 6   Dunhill Vacations Inc.                                   [START PLANNING]
# 7     Senator Scott Wiener  [Join the re-election campaign as a founding d...
# 8   Dunhill Vacations Inc.  [Book a cruise with Fall Sale Extras by Novemb...
# 9               Matt Haney               [visit my website, send me an email]
# 10                   Apple                                 [Claim Reward Now]
# 11         Angelina Petrov  [View loan options with a simple 2-minute appl...
# 12                Al.Nabil  [Reply to discuss potential partnership and in...
# 13     US Finance Solution  [Apply for an interest only line of credit up ...
# 14                   Tanya  [Share missing features or functionality in Ne...
# 15              Sam at EMC  [Tell us about your business and explore your ...
# 16         The iCloud Team                  [Update your payment information]
# 17    Senator Scott Wiener  [Buy tickets for the Craft Beer Bash, RSVP for...
# 18                  Norton                                        [Renew Now]
# 19              Sam at EMC  [Fill out the 5-minute application on EMC Fina...
# 20           Bamboo Spa SF  [View Offer, Join the reopening celebration, R...
# 21                  Intuit  [Access your free credit score with Credit Kar...
# 22            EMC Research  [Participate in a short survey about local tra...
# 23          RedWordle Team  [Solve the RedWordle #4 puzzle, Learn about re...
# 24         Angelina Petrov  [Check your Eligibility, Complete the applicat...
# 25     US Finance Solution  [Access the online portal for funding offers, ...
# 26           Niantic, Inc.  [Challenge Mega Gengar and Mega Banette in Meg...
# 27           Basil the Bat  [Play RedWordle, Download redwood-inspired Jac...
# 28              Matt Haney               [visit my website, send me an email]
# 29              Sam at EMC  [Kickstart your funding application now and se...
# 30          Jennifer Trott  [Register for the Future of SaaS Management Pl...
# 31        Champion Advance  [Start the financing process by using the atta...
# 32           EMC Financial  [Check out our low-rate financing options, GET...
# 33       Uber Technologies  [Choose Uber Comfort Electric for your next ri...
# 34                    None  [Take advantage of the Early Discount, Start s...
# 35                    None  [Save up to 25% off a luxurious suite, Become ...
# 36                    None  [Book culinary tours by November 30th for up t...
# 37  Dunhill Vacations Inc.  [Consider booking a 4 or 5 night long-to-extra...
# 38              Tim Whalen  [Consider all ways to give to Save the Redwood...
# 39         Crunchbase Team  [Review the new versions of the governing term...
# 40              Sam at EMC  [Fill out this application and explore your fi...
# 41                     Sam  [Determine your financing eligibility, Get sta...
#
#                       reference.output.sender_address  \
# 0                     42 Broadway, New York, NY 10004
# 1   475 Washington Blvd, Suite 7, Marina Del Rey, ...
# 2             9101 W. Sahara Ave, Las Vegas, NV 89117
# 3                     42 Broadway, New York, NY 10004
# 4   University Advancement, Princeton University, ...
# 5                     75 Broad St, New York, NY 10004
# 6   2307 W. Broward Blvd, Ste 402 - Fort Lauderdal...
# 7   312 Clay St., Suite 300, Oakland, CA 94607, Un...
# 8   2307 W. Broward Blvd, Ste 402 - Fort\nLauderda...
# 9   Capitol Office: 1021 O Street, Suite 5310, P.O...
# 10  6101 Long Prairie Rd,Ste 744 #511, Flower Moun...
# 11                 44 Wall Street, New York, NY 10005
# 12                                              Syria
# 13    1501 Hamburg Turnpike Suite 301 Wayne, NJ 07470
# 14                                               None
# 15  475 Washington Blvd, Suite 7, Marina Del Rey, ...
# 16  6101 Long Prairie Rd,Ste 744 #511, Flower Moun...
# 17          312 Clay St. Suite 300, Oakland, CA 94607
# 18                                               None
# 19  475 Washington Blvd, Suite 7, Marina Del Rey, ...
# 20             2284 Union St, San Francisco, CA 94123
# 21    2800 E. Commerce Center Place, Tucson, AZ 85706
# 22                                               None
# 23  111 Sutter Street, 11th Floor, San Francisco, ...
# 24                 44 Wall Street, New York, NY 10005
# 25                                               None
# 26        One Ferry Building, San Francisco, CA 94111
# 27  111 Sutter Street, 11th Floor, San Francisco, ...
# 28  Capitol Office: 1021 O Street, Suite 5310, P.O...
# 29  475 Washington Blvd, Suite 7, Marina Del Rey, ...
# 30      Tornimae 5, 2nd floor Tallinn, Estonia, 10145
# 31                    42 Broadway, New York, NY 10004
# 32  475 Washington Blvd, Suite 7, Marina Del Rey, ...
# 33              1515 3rd St., San Francisco, CA 94158
# 34                                               None
# 35    3355 Las Vegas Blvd. S. Las Vegas, Nevada 89109
# 36  2307 W. Broward Blvd, Ste 402 - Fort\nLauderda...
# 37  2307 W. Broward Blvd, Ste 402 - Fort Lauderdal...
# 38  111 Sutter Street, 11th Floor, San Francisco, ...
# 39                                               None
# 40  475 Washington Blvd, Suite 7, Marina Del Rey, ...
# 41  475 Washington Blvd, Suite 7, Marina Del Rey, ...
#
#    reference.output.sender_phone_number output.output.sender_phone_number
# 0                          888-422-2162                               NaN
# 1                        (310) 491-7947                               NaN
# 2                                  None                               NaN
# 3                          888-422-2162                               NaN
# 4                                  None                               NaN
# 5                                  None                               NaN
# 6                                  None                               NaN
# 7                                  None                               NaN
# 8                                  None                               NaN
# 9                                  None                               NaN
# 10                                 None                               NaN
# 11                       (646) 349-6626                    (646) 349-6626
# 12                                 None                               NaN
# 13                       (516) 272-2110                    (516) 272-2110
# 14                                 None                               NaN
# 15                       (310) 491-7947                    (310) 491-7947
# 16                                 None                               NaN
# 17                                 None                               NaN
# 18                                 None                               NaN
# 19                                 None                               NaN
# 20                         415-567-8812                      415-567-8812
# 21                                 None                               NaN
# 22                                 None                               NaN
# 23                         415-362-2352                               NaN
# 24                       (646) 349-6626                    (646) 349-6626
# 25                       (516) 272-2110                    (516) 272-2110
# 26                                 None                               NaN
# 27                         415-362-2352                               NaN
# 28                       (916) 319-2017                               NaN
# 29                                 None                               NaN
# 30                                 None                               NaN
# 31                         888-422-2162                               NaN
# 32                         800.761.3108                               NaN
# 33                                 None                               NaN
# 34                                 None
# 35                                 None                               NaN
# 36                                 None                               NaN
# 37                                 None                               NaN
# 38                         415-362-2352                      415-362-2352
# 39                                 None                               NaN
# 40                                 None                               NaN
# 41                         800.761.3108                               NaN

# %% [markdown]
# An example of a poorly behaving agent that seems to have gotten stuck in a loop!
